# %%
import pandas as pd
data = pd.read_csv('data/data.full.csv', dtype={'binary': str}).set_index('seq')
data
# Out:
#                                             Sequences      RA_1      RA_2  \
# seq
# AGCGCGAAAACACAAC  UAUCACAGCGCGUAAAACACAAUGGAUGGGUCGAA  0.296563  0.312593
# AGCGCGAAAACACAAU  UAUCACAGCGCGUAAAACACAAUGGAUGGGUUGAA  0.317296  0.371002
# AGCGCGAAAACACAUC  UAUCACAGCGCGUAAAACACAUUGGAUGGGUCGAA  0.280970  0.270548
# AGCGCGAAAACACAUU  UAUCACAGCGCGUAAAACACAUUGGAUGGGUUGAA  0.319805  0.397730
# AGCGCGAAAACACUAC  UAUCACAGCGCGUAAAACACUAUGGAUGGGUCGAA  0.506120  0.559888
# ...                                               ...       ...       ...
# UUGUUUUGGCGGUAUU  UAUCACUUGUUUUUGGCGGUAUUGGAUGGGUUGAA  0.015198  0.047795
# UUGUUUUGGCGGUUAC  UAUCACUUGUUUUUGGCGGUUAUGGAUGGGUCGAA  0.129357  0.182552
# UUGUUUUGGCGGUUAU  UAUCACUUGUUUUUGGCGGUUAUGGAUGGGUUGAA  0.036140  0.067013
# UUGUUUUGGCGGUUUC  UAUCACUUGUUUUUGGCGGUUUUGGAUGGGUCGAA  0.010448  0.045240
# UUGUUUUGGCGGUUUU  UAUCACUUGUUUUUGGCGGUUUUGGAUGGGUUGAA  0.017948  0.019403
#
#                          m       var            binary     ypred
# seq
# ...

# %%
seqs = data["Sequences"]
seqs
# Out:
# seq
# AGCGCGAAAACACAAC    UAUCACAGCGCGUAAAACACAAUGGAUGGGUCGAA
# AGCGCGAAAACACAAU    UAUCACAGCGCGUAAAACACAAUGGAUGGGUUGAA
# AGCGCGAAAACACAUC    UAUCACAGCGCGUAAAACACAUUGGAUGGGUCGAA
# AGCGCGAAAACACAUU    UAUCACAGCGCGUAAAACACAUUGGAUGGGUUGAA
# AGCGCGAAAACACUAC    UAUCACAGCGCGUAAAACACUAUGGAUGGGUCGAA
#                                    ...
# UUGUUUUGGCGGUAUU    UAUCACUUGUUUUUGGCGGUAUUGGAUGGGUUGAA
# UUGUUUUGGCGGUUAC    UAUCACUUGUUUUUGGCGGUUAUGGAUGGGUCGAA
# UUGUUUUGGCGGUUAU    UAUCACUUGUUUUUGGCGGUUAUGGAUGGGUUGAA
# UUGUUUUGGCGGUUUC    UAUCACUUGUUUUUGGCGGUUUUGGAUGGGUCGAA
# UUGUUUUGGCGGUUUU    UAUCACUUGUUUUUGGCGGUUUUGGAUGGGUUGAA
# Name: Sequences, Length: 65536, dtype: object

# %%
seqs.to_csv("ribozyme_seqs.tsv",sep="\t")
